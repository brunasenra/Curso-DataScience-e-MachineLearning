# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(0, 5, 11)
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y = x*x
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plot.xlabel('Eixo x')
plot.ylabel('Eixo y')
plt.title('Título')

# %%
plt.plot(x,y, color = 'r')

# %%
plt.plot(x,y,'r--')

# %%
#plt.subplot(nrows=1, ncols=2)
plt.subplot(1,2,1)    #o terceiro elemento se refere a qual gráfico será usado a seguir.
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.plot(y,x,'g*-')

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axes.set_xlabel('Eixo x')
axes.set_title('Título')
# Out:
# Text(0.5, 1.0, 'Título')

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.3,0.3])

axes1.plot(x,y)
axes1.set_xlabel('Eixo x')
axes1.set_title('Título')
axes2.plot(y,x)

# %%
fig, ax = plt.subplots()
ax.plot(x,x**3,'b--')
ax.plot(x,x**4, 'g--')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Título')
# Out:
# Text(0.5, 1.0, 'Título')
